# %% [markdown]
# # Lab 6: Generate Synthetic Queries with Misspellings

# %%
import pandas as pd
import re
import json
import ollama

# %% [markdown]
# ## 1. Data Loading

# %%
df = pd.read_csv('web_search_queries.csv')
print(f"Loaded {len(df)} queries")
df.head(50)
# Out:
# Loaded 45 queries
#                              Topic  \
# 0                       Map Search
# 1                       Map Search
# 2                       Map Search
# 3                       Map Search
# 4                       Map Search
# 5                       Job Search
# 6                       Job Search
# 7                       Job Search
# 8                       Job Search
# 9                       Job Search
# 10                   Flight Search
# 11                   Flight Search
# 12                   Flight Search
# 13                   Flight Search
# 14                   Flight Search
# 15                      E-commerce
# 16                      E-commerce
# 17                      E-commerce
# 18                      E-commerce
# 19                      E-commerce
# 20              Health and Fitness
# 21              Health and Fitness
# 22              Health and Fitness
# 23              Health and Fitness
# 24              Health and Fitness
# 25         Entertainment and Media
# 26         Entertainment and Media
# 27         Entertainment and Media
# 28         Entertainment and Media
# 29         Entertainment and Media
# 30              Travel and Tourism
# 31              Travel and Tourism
# 32              Travel and Tourism
# 33              Travel and Tourism
# 34              Travel and Tourism
# 35  General Knowledge and Learning
# 36  General Knowledge and Learning
# 37  General Knowledge and Learning
# 38  General Knowledge and Learning
# 39  General Knowledge and Learning
# 40                  Local Services
# 41                  Local Services
# 42                  Local Services
# 43                  Local Services
# 44                  Local Services
#
#                                                 Query
# 0                       restaurants near Central Park
# 1     shortest route to Times Square from JFK Airport
# 2    petrol stations open now in downtown Los Angeles
# 3   walking directions to Eiffel Tower from Louvre...
# 4     nearest hiking trails in Yosemite National Park
# 5             software engineer jobs in San Francisco
# 6              remote work opportunities in marketing
# 7     freelance graphic design projects for beginners
# 8                  data scientist positions at Google
# 9   entry-level mechanical engineering jobs in Austin
# 10              cheap flights from New York to London
# 11          nonstop flights to Tokyo from Los Angeles
# 12          business class deals to Paris in December
# 13            flights under $500 to Hawaii in January
# 14     flight schedules for Delta Airlines to Chicago
# 15                           best laptops under $1000
# 16        organic skincare products with good reviews
# 17          discounted furniture for small apartments
# 18          latest iPhone models with trade-in offers
# 19              top-rated noise-cancelling headphones
# 20                               yoga classes near me
# 21               gyms with personal trainers in Miami
# 22           low-carb meal prep ideas for weight loss
# 23                 home remedies for back pain relief
# 24                   best running shoes for flat feet
# 25                movies playing near me this weekend
# 26                   top-rated fantasy novels of 2024
# 27                     concerts in Chicago this month
# 28         free streaming platforms for documentaries
# 29                 latest episodes of Stranger Things
# 30                   best hotels in Bali for families
# 31                      top-rated attractions in Rome
# 32             all-inclusive resorts in the Caribbean
# 33  visa requirements for US citizens visiting Canada
# 34              weather forecast for Cancun next week
# 35                 history of the Great Wall of China
# 36                   how to solve quadratic equations
# 37                  current events in the Middle East
# 38         free online courses for Python programming
# 39                  most famous paintings by Van Gogh
# 40                 plumbers near me with good reviews
# 41                       24-hour pharmacies in Boston
# 42                      car repair shops in San Diego
# 43       affordable wedding photographers in New York
# 44                       dog groomers open on Sundays

# %% [markdown]
# ## 2. Abbreviation Detection

# %%
KNOWN_ABBREVIATIONS = {
    'JFK', 'LAX', 'SFO', 'ORD', 'DFW', 'ATL', 'LHR', 'CDG',
    'NBC', 'CBS', 'ABC', 'CNN', 'BBC', 'HBO', 'IBM',
    'NASA', 'FBI', 'CIA', 'USPS', 'UPS',
    'AI', 'ML', 'NLP', 'API', 'URL', 'HTML', 'CSS', 'SQL',
    'TV', 'DVD', 'CEO', 'HR', 'IT', 'FAQ',
}

def find_protected_words(query: str) -> list:
    protected = []
    for word in query.split():
        clean = re.sub(r'[^a-zA-Z]', '', word).upper()
        if clean in KNOWN_ABBREVIATIONS:
            protected.append(word)
    return protected


print(find_protected_words("shortest route from JFK Airport"))
# Out:
# ['JFK']

# %% [markdown]
# ## 3. LLM-Based Misspelling Generator

# %%
def generate_misspellings(query: str, n: int = 5, model: str = "llama3") -> list:
    protected = find_protected_words(query)
    protected_str = ', '.join(protected) if protected else 'none'
    
    prompt = f"""Generate exactly {n} misspelling variants of this query:
"{query}"

CRITICAL: These words must stay EXACTLY as-is, do not change them: [{protected_str}]
Include: omission (like: machine->machin), transposition (like: the->teh), phonetic (like: phone->fone), repetition (like: running->runnning)
Each variant: 1-3 typos in OTHER words only.

Return ONLY JSON array: ["variant1", "variant2", ...]"""
    
    response = ollama.chat(model=model, messages=[{'role': 'user', 'content': prompt}])
    content = response['message']['content']
    
    match = re.search(r'\[.*?\]', content, re.DOTALL)
    if match:
        try:
            return json.loads(match.group())[:n]
        except:
            pass
    return re.findall(r'"([^"]+)"', content)[:n]

# %%
MODEL = "llama3" #"mistral"

test_queries = [
    "machine learning applications",
    "shortest route to Times Square from JFK Airport",
    "software engineer jobs in San Francisco",
]

for query in test_queries:
    print(f"\nOriginal: {query}")
    print(f"Protected: {find_protected_words(query)}")
    for i, v in enumerate(generate_misspellings(query, n=5, model=MODEL), 1):
        print(f"  {i}. {v}")
# Out:
# Original: machine learning applications
# Protected: []
#   1. machin learing applications
#   2. machine learnign applicaitons
#   3. macnine learning appications
#   4. machien learning appliacations
#   5. machines lerning appliations
#
# Original: shortest route to Times Square from JFK Airport
# Protected: ['JFK']
#   1. shortest rout to Times Squair from JFk Airport
#   2. shorrest route to Time Square from JFK Air Port
#   3. shortesrt route to Timmes Square from JKf airport
#   4. shortest rote to Tiimes Square from FKJ Airport
#   5. shotest route to Tymes Sqare from JFK Aiport
#
# Original: software engineer jobs in San Francisco
# Protected: []
#   1. softwear engineeer jobs in San Fransico
#   2. software engenier jobz in San Franiscso
#   3. sworfeware engineerin' jobs in San Frahisco
#   4. softwar engineer joobs in Sah Francisco
#   5. sofware enjinieer jobs in San Fancisco

# %%
# test
MODEL = "mistral"

test_queries = [
    "machine learning applications",
    "shortest route to Times Square from JFK Airport",
    "software engineer jobs in San Francisco",
]

for query in test_queries:
    print(f"\nOriginal: {query}")
    print(f"Protected: {find_protected_words(query)}")
    for i, v in enumerate(generate_misspellings(query, n=5, model=MODEL), 1):
        print(f"  {i}. {v}")
# Out:
# Original: machine learning applications
# Protected: []
#   1. machin learning applications
#   2. machine learnings applicatons
#   3. machine learing applcations
#   4. machine learning appilcations
#   5. machine learing applications
#
# Original: shortest route to Times Square from JFK Airport
# Protected: ['JFK']
#   1. shortest route to Time Square from JFK Airport
#   2. shortest rout to Times Squre from JFK Airpot
#   3. shortest route to Tims Square from JFK Airpot
#   4. shortest route to Times Squar from JFK Airport
#   5. shortest route to Times Square form JFK Airport
#
# Original: software engineer jobs in San Francisco
# Protected: []
#   1. software enginer jobs in San Francico
#   2. software engineer jabs in San Francisco
#   3. software enginner jobs in San Franscisco
#   4. software engineer jobs in San Frantisco
#   5. software engineer job in San Francisco

# %% [markdown]
# ## 4. Process All Queries

# %%
def process_all_queries(df, n_variants=5, model="llama3"):
    results = []
    for _, row in df.iterrows():
        variants = generate_misspellings(row['Query'], n=n_variants, model=model)
        for i, v in enumerate(variants):
            results.append({'topic': row['Topic'], 'original': row['Query'], 
                           'variant_id': i+1, 'variant': v, 'model': model})
    return pd.DataFrame(results)

results_df = process_all_queries(df.head(50), n_variants=3, model=MODEL)
results_df
# Out:
#               topic                                         original  \
# 0        Map Search                    restaurants near Central Park
# 1        Map Search                    restaurants near Central Park
# 2        Map Search                    restaurants near Central Park
# 3        Map Search  shortest route to Times Square from JFK Airport
# 4        Map Search  shortest route to Times Square from JFK Airport
# ..              ...                                              ...
# 130  Local Services     affordable wedding photographers in New York
# 131  Local Services     affordable wedding photographers in New York
# 132  Local Services                     dog groomers open on Sundays
# 133  Local Services                     dog groomers open on Sundays
# 134  Local Services                     dog groomers open on Sundays
#
#      variant_id                                        variant   model
# 0             1                  resturants neer Centrail Park  llama3
# 1             2                resaturants near Centreal Parke  llama3
# 2             3                   restrant's near Centrul PArk  llama3
# 3             1  shortest rute to Times Squre from JKF Airport  llama3
# 4             2  shoret routhe to Time Square from JFK Airport  llama3
# ..          ...                                            ...     ...
# 130           2     afordable wdding photograhers in New Yorkk  llama3
# 131           3  afrordable weddinng photagraphes in Neyw York  llama3
# 132           1                   dog greemers open on Sundaze  llama3
# 133           2                    dog groomes opwn on Sundays  llama3
# 134           3                 dog grrommers open on Saturnds  llama3
#
# [135 rows x 5 columns]

# %%
results_df1 = process_all_queries(df.head(50), n_variants=3, model="mistral")
results_df_=pd.concat([results_df,results_df1])
results_df_.to_csv("results_week6lab2.csv")
results_df_
# Out:
#               topic                                         original  \
# 0        Map Search                    restaurants near Central Park
# 1        Map Search                    restaurants near Central Park
# 2        Map Search                    restaurants near Central Park
# 3        Map Search  shortest route to Times Square from JFK Airport
# 4        Map Search  shortest route to Times Square from JFK Airport
# ..              ...                                              ...
# 128  Local Services     affordable wedding photographers in New York
# 129  Local Services     affordable wedding photographers in New York
# 130  Local Services                     dog groomers open on Sundays
# 131  Local Services                     dog groomers open on Sundays
# 132  Local Services                     dog groomers open on Sundays
#
#      variant_id                                        variant    model
# 0             1                  resturants neer Centrail Park   llama3
# 1             2                resaturants near Centreal Parke   llama3
# 2             3                   restrant's near Centrul PArk   llama3
# 3             1  shortest rute to Times Squre from JKF Airport   llama3
# 4             2  shoret routhe to Time Square from JFK Airport   llama3
# ..          ...                                            ...      ...
# 128           2     affordable wedding phographers in New Yotk  mistral
# 129           3     affordable weding photograpers in New York  mistral
# 130           1                  dog groomers open on Sundaies  mistral
# 131           2                   dog groomers opes on Sundays  mistral
# 132           3                   dog groomers open on Sundayz  mistral
#
# [268 rows x 5 columns]

# %% [markdown]
# ## 5. Multi-Model Comparison

# %%
def check_protected_preserved(original: str, variant: str) -> bool:
    for word in find_protected_words(original):
        if word not in variant:
            return False
    return True

def analyze_error_types(original: str, variant: str) -> list:
    errors = []
    for ow, vw in zip(original.lower().split(), variant.lower().split()):
        if len(vw) < len(ow): errors.append('omission')
        elif len(vw) > len(ow): errors.append('repetition')
        elif ow != vw:
            errors.append('transposition' if sorted(ow) == sorted(vw) else 'substitution')
    return list(set(errors))

# %%
MODELS = ["llama3"]  
TEST_QUERY = "shortest route to Times Square from JFK Airport"
N=50
for model in MODELS:
    print(f"\n=== {model} ===")
    try:
        variants = generate_misspellings(TEST_QUERY, n=N, model=model)
        preserved_count = 0
        for v in variants:
            preserved = check_protected_preserved(TEST_QUERY, v)
            preserved_count += preserved
            status = "✓" if preserved else "✗"
            errors = analyze_error_types(TEST_QUERY, v)
            print(f"  {status} {v} [{', '.join(errors)}]")
        print(f"  Protected preserved: {preserved_count}/{N}")
    except Exception as e:
        print(f"  Error: {e}")
# Out:
# === llama3 ===
#   ✗ shorist rout to Times Square from JKF Airport [omission, transposition]
#   ✓ shortest rute to Time Squre from JFK Airpot [omission]
#   ✗ shotest rout to Tims Square from JKf Airport [omission, transposition]
#   ✓ shiortest route to Times Sqaure from JFK Arpoirt [repetition, transposition]
#   ✗ shorturst rouete to Times Sqare from JFk Airport [omission, repetition]
#   ✓ shourtest route to Timze Square from JFK Aiprport [repetition, substitution]
#   ✗ schorist route to Time Squre from JKF Airpordt [omission, repetition, transposition, substitution]
#   ✗ shorest rout to Timsqurare from JKf Airpotr [omission, repetition]
#   ✓ shorteset rout to Times Squear from JFK Airopirt [omission, repetition, transposition]
#   ✗ shotest rouete to Timze Square from JFk Aipport [omission, repetition, substitution]
#   ✓ shorist rooute to Time Squre from JFK Arpoirtt [omission, repetition]
#   ✗ shorest route to Timsqurare from JKf Airpordt [omission, repetition]
#   ✗ shorturst rout to Times Sqare from JKF Airopirt [omission, repetition, transposition]
#   ✓ shourtest rouete to Timze Squear from JFK Aipportt [repetition, transposition, substitution]
#   ✗ schorist rooute to Time Squre from JFk Arpoirt [omission, repetition, transposition, substitution]
#   ✗ shorteset route to Timsqurare from JKf Airpotr [omission, repetition]
#   ✓ shotest route to Times Sqare from JFK Airopirtt [omission, repetition]
#   ✗ shorist rouete to Timze Squear from JKF Aipport [omission, repetition, transposition, substitution]
#   ✗ shorest rout to Time Squre from JKf Arpoirtt [omission, repetition, transposition]
#   ✗ shorturst rooute to Timsqurare from JFk Airpotr [omission, repetition]
#   ✓ schorist route to Times Sqare from JFK Airopirtt [omission, repetition, substitution]
#   ✗ shotest rooute to Timze Squear from JKf Aipport [omission, repetition, transposition, substitution]
#   ✗ shorest route to Time Squre from JKF Arpoirtt [omission, repetition, transposition]
#   ✗ shorteset rouete to Timsqurare from JFk Airpotr [omission, repetition]
#   ✓ shorist route to Times Sqare from JFK Airoportt [omission, repetition]
#   ✗ shotest rooute to Timze Squear from JKf Aipportt [omission, repetition, transposition, substitution]
#   ✗ schorist rout to Time Squre from JFk Arpoirt [omission, transposition, substitution]
#   ✗ shorturst route to Timsqurare from JKf Airpotr [omission, repetition]
#   ✓ shourtest rouete to Times Sqare from JFK Airoport [omission, repetition]
#   ✗ shorest rooute to Timze Squear from JKF Aipportt [omission, repetition, transposition, substitution]
#   ✗ shorteset rout to Time Squre from JKf Arpoirtt [omission, repetition, transposition]
#   ✗ schorist rouete to Timsqurare from JFk Airpotr [omission, repetition, substitution]
#   ✓ shotest route to Timze Sqare from JFK Airoportt [omission, repetition, substitution]
#   ✗ shorist rooute to Time Squear from JKf Aipport [omission, repetition, transposition, substitution]
#   ✗ shorest rout to Times Sqare from JKF Arpoirtt [omission, repetition, transposition]
#   ✗ schorist rooute to Timsqurare from JFk Airopotrt [omission, repetition, substitution]
#   ✗ shotest rouete to Timze Squear from JKf Aipport [omission, repetition, transposition, substitution]
#   ✓ shorturst route to Time Squre from JFK Airpotr [omission, repetition, transposition]
#   ✗ shourtest rout to Times Sqare from JKF Arpoirtt [omission, repetition, transposition]
#   ✗ shorest rooute to Timsqurare from JFk Airopotrt [omission, repetition]
#   ✓ shorteset rouete to Timze Squear from JFK Aipport [repetition, transposition, substitution]
#   ✗ schorist route to Timsqurare from JKf Arpoirtt [omission, repetition, substitution]
#   ✗ shotest rout to Time Squre from JKF Airpotr [omission, transposition]
#   ✗ shorist rooute to Timze Sqare from JFk Airopotrt [omission, repetition, substitution]
#   ✓ shorest route to Times Squear from JFK Aipportt [omission, repetition, transposition]
#   ✗ schorist rouete to Timsqurare from JKf Arpoirt [omission, repetition, substitution]
#   Protected preserved: 14/50

# %%
MODELS = ["mistral"]  
TEST_QUERY = "shortest route to Times Square from JFK Airport"
N=26
for model in MODELS:
    print(f"\n=== {model} ===")

    variants = generate_misspellings(TEST_QUERY, n=N, model=model)
    preserved_count = 0
    for v in variants:
        preserved = check_protected_preserved(TEST_QUERY, v)
        preserved_count += preserved
        status = "✓" if preserved else "✗"
        errors = analyze_error_types(TEST_QUERY, v)
        print(f"  {status} {v} [{', '.join(errors)}]")
    print(f"  Protected preserved: {preserved_count}/{len(variants)}")
# Out:
# === mistral ===
#   ✓ shortest route to Times Square from JFK Airpot [omission]
#   ✓ shoertest rout to Time Square from JFK Airport [omission, repetition]
#   ✓ shortest route to Tines Square from JFK Airport [substitution]
#   ✓ shortest rute to Times Square from JFK Airport [omission]
#   ✓ shortest route too Times Square from JFK Airport [repetition]
#   ✓ shortest route to Timess Square from JFK Airport [repetition]
#   ✓ shortest route to Time Squre from JFK Airport [omission]
#   ✓ shorrest rout to Times Square from JFK Airpot [omission, substitution]
#   ✓ shorthst route to Tines Square from JFK Airport [substitution]
#   ✓ shortest rout too Timess Square from JFK Airport [omission, repetition]
#   ✓ shortest route to Timess Squre from JFK Airport [omission, repetition]
#   ✓ shortest route to Time Squr from JFK Airport [omission]
#   ✓ shortest rout to Times Sqare from JFK Airpot [omission]
#   ✓ shortest rout too Tines Sqare from JFK Airport [omission, repetition, substitution]
#   ✓ shortest rout too Timess Sqare from JFK Airpot [omission, repetition]
#   ✓ shortest rout too Time Squr from JFK Airport [omission, repetition]
#   ✓ shortest rout too Times Sqare from JFK Airpot [omission, repetition]
#   ✓ shorrest route to Times Square from JFK Airpot [omission, substitution]
#   ✓ shorrest rout to Tines Square from JFK Airport [omission, substitution]
#   ✓ shorrest rout too Timess Square from JFK Airport [omission, repetition, substitution]
#   ✓ shorrest rout too Time Squr from JFK Airport [omission, repetition, substitution]
#   ✓ shorrest rout too Times Sqare from JFK Airpot [omission, repetition, substitution]
#   Protected preserved: 22/22

# %%
MODELS = ["mistral"]  
TEST_QUERY = "free streaming plaftorms for documentary"
N=50
for model in MODELS:
    print(f"\n=== {model} ===")
    try:
        variants = generate_misspellings(TEST_QUERY, n=N, model=model)
        preserved_count = 0
        for v in variants:
            preserved = check_protected_preserved(TEST_QUERY, v)
            preserved_count += preserved
            status = "✓" if preserved else "✗"
            errors = analyze_error_types(TEST_QUERY, v)
            print(f"  {status} {v} [{', '.join(errors)}]")
        print(f"  Protected preserved: {preserved_count}/{N}")
    except Exception as e:
        print(f"  Error: {e}")
# Out:
# === mistral ===
#   ✓ free streaming platfroms for documentary [transposition]
#   ✓ free streaming plaftorms for documetary [omission]
#   ✓ free streaming platfomrs for documentry [omission, transposition]
#   ✓ free streaming plaftorms for documentary []
#   ✓ free streaming plaftorms for doocumentary [repetition]
#   ✓ free streaming platfoms for documetnary [omission, transposition]
#   ✓ free streaming plaftorms for documentarie [repetition]
#   ✓ free streaming platfroms for documetaryy [transposition, substitution]
#   ✓ free streaming platfroms for documeny [omission, transposition]
#   ✓ free streaming platfroms for doocumentaries [repetition, transposition]
#   ✓ free streaming platfroms for documentariesy [repetition, transposition]
#   ✓ free streaming platfroms for documentarites [repetition, transposition]
#   ✓ free streaming platfroms for documentariesies [repetition, transposition]
#   ✓ free streaming platfroms for documetaryi [transposition, substitution]
#   ✓ free streaming platfroms for documentaryie [repetition, transposition]
#   ✓ free streaming platfroms for doocumentaries [repetition, transposition]
#   ✓ free streaming platfroms for documetnaries [repetition, transposition]
#   ✓ free streaming platfroms for documetarie [transposition, substitution]
#   ✓ free streaming platfroms for doocumentarties [repetition, transposition]
#   ✓ free streaming platfroms for documentarries [repetition, transposition]
#   ✓ free streaming platfroms for doocumetary [transposition, substitution]
#   ✓ free streaming platfroms for doocumentariesy [repetition, transposition]
#   ✓ free streaming platfroms for doocumentaryi [repetition, transposition]
#   ✓ free streaming platfroms for doocumentaryie [repetition, transposition]
#   ✓ free streaming platfroms for documetarties [repetition, transposition]
#   ✓ free streaming platfroms for documentarriesies [repetition, transposition]
#   ✓ free streaming platfroms for documentariesoi [repetition, transposition]
#   ✓ free streaming platfroms for documentariesei [repetition, transposition]
#   ✓ free streaming platfroms for documetaryo [transposition, substitution]
#   ✓ free streaming platfroms for doocumentartie [repetition, transposition]
#   Protected preserved: 30/50

# %% [markdown]
# ## 6. Search Engine Testing

# %%
import urllib.parse

query = "machine learning applications"
variants = generate_misspellings(query, n=3, model=MODEL)

print(f"Original: https://www.google.com/search?q={urllib.parse.quote(query)}")
for i, v in enumerate(variants, 1):
    print(f"Variant {i}: https://www.google.com/search?q={urllib.parse.quote(v)}")
# Out:
# Original: https://www.google.com/search?q=machine%20learning%20applications
# Variant 1: https://www.google.com/search?q=machien%20lerning%20applicaitons
# Variant 2: https://www.google.com/search?q=maachine%20leerinig%20appliacations
# Variant 3: https://www.google.com/search?q=machiene%20learnin%20appilications

# %%
https://www.google.com/search?q=shoret+routhe+to+Time+Square+from+JFK+Airpor&oq=shoret+routhe+to+Time+Square+from+JFK+Airpor
